# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
sns.displot(df['Age'], kde = True, color = "blue")
# Out:
# C:\Users\Anonymous\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(x = df["RestingBP"], kde = True, color = "Green")
# Out:
# C:\Users\Anonymous\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['Cholesterol'], kde = True, color = 'pink')
# Out:
# C:\Users\Anonymous\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['FastingBS'], kde = True, color = "violet")
# Out:
# C:\Users\Anonymous\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['MaxHR'], kde = True, color = 'red')
# Out:
# C:\Users\Anonymous\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['Oldpeak'], kde = True, color = 'orange')
# Out:
# C:\Users\Anonymous\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['HeartDisease'], kde = True, color = 'Yellow')
# Out:
# C:\Users\Anonymous\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.groupby('Sex').size().plot(kind = 'pie', autopct = '%0.1f', figsize = (6,6))
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind = 'pie', autopct = '%0.1f', figsize = (6,6))
# Out:
# <Axes: >

# %%
df.groupby('FastingBS').size().plot(kind = 'pie', autopct = '%0.1f', figsize = (6,6))
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind = 'pie', autopct = '%0.1f', figsize = (6,6))
# Out:
# <Axes: >

# %%
df.groupby('ExerciseAngina').size().plot(kind = 'pie', autopct = '%0.1f', figsize = (6,6))
# Out:
# <Axes: >

# %%
df.groupby('ST_Slope').size().plot(kind = 'pie', autopct = '%0.1f', figsize = (6,6))
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie', autopct = '%0.1f', figsize = (6,6))
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
sns.violinplot(x = df["Age"])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(x = df['HeartDisease'], y = df['Age'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(y = df['Sex'], x = df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(x = df['HeartDisease'], y = df['Cholesterol'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(x = df['HeartDisease'], y = df['RestingBP'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='RestingBP'>

# %%
sns.violinplot(x = df['HeartDisease'], y = df['FastingBS'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='FastingBS'>

# %%
sns.violinplot(x = df['HeartDisease'], y = df['MaxHR'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='MaxHR'>

# %%
sns.violinplot(x = df['HeartDisease'], y = df['Oldpeak'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Oldpeak'>

# %%
df.corr(numeric_only = True)
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.corr(numeric_only = True))
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
sns.jointplot(x = 'Age', y = 'Sex', data = df)

# %%
sns.jointplot(x = 'Age', y = 'ChestPainType', data = df)

# %%
sns.jointplot(x = 'Age', y = 'MaxHR', data = df, kind = 'hex')

# %%
sns.jointplot(x = 'Age', y = 'MaxHR', data = df, kind = 'reg')

# %%
sns.jointplot(x = 'Age', y = 'RestingBP', data = df)

# %%
sns.jointplot(x = 'Age', y = 'RestingBP', data =df, kind = 'reg')

# %%
sns.jointplot(x = 'Cholesterol', y = 'HeartDisease', data = df, kind = 'reg')

# %%
sns.pairplot(df)
# Out:
# C:\Users\Anonymous\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
